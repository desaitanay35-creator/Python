# %%
import numpy as np
import pandas as pd
import seaborn as sns
pd.__version__
# Out:
# '2.3.3'

# %%
df=pd.DataFrame(np.random.randint(1,100,(8,5)),columns=['A','B','C','D','E'])
print(df.shape)
# Out:
# (8, 5)

# %%
print(df.size)
print(df.ndim)
df['sum']=df['A']+df['B']+df['C']+df['D']+df['E']
df
# Out:
# 40
# 2
#     A   B   C   D   E  sum
# 0  32  52  73   9  71  237
# 1  66  33  92  38  31  260
# 2  83  28   6  27   2  146
# 3  24  66  74  43  70  277
# 4  59  72  21  16  77  245
# 5  53   6  34  20  19  132
# 6  21  73  69  19  62  244
# 7  44  55  70  88  96  353

# %%
df.iloc[5,2]=70
df.loc[2:7,'B':'D']
df.loc[10]=[70,20,50,30,20,100]
df
# Out:
#      A   B   C   D   E  sum
# 0   32  52  73   9  71  237
# 1   66  33  92  38  31  260
# 2   83  28   6  27   2  146
# 3   24  66  74  43  70  277
# 4   59  72  21  16  77  245
# 5   53   6  70  20  19  132
# 6   21  73  69  19  62  244
# 7   44  55  70  88  96  353
# 10  70  20  50  30  20  100

# %%
    
df=pd.DataFrame(np.random.randint(1,100,(5,5)),columns=['A','B','C','D','E'])
df
# Out:
#     A   B   C   D   E
# 0  67  59  74  64  42
# 1  48   4  87  60  14
# 2   6  89  49  24  50
# 3  50  29  44  28   2
# 4   4  70  89  23  20

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#        ID   W    G    R    AB     H    1B   2B  3B   HR  ...  HBP  BBHBP  SF  \
# 0       1  60  162  558  5336  1280   891  247  31  111  ...    0    460   0
# 1       3  86  161  677  5620  1492  1147  216  46   83  ...    0    531   0
# 2       5  79  162  679  5550  1496  1088  262  63   83  ...    0    543   0
# 3       7  96  162  780  5536  1458   990  265  40  163  ...    0    561   0
# 4       9  96  162  688  5441  1354   905  247  21  181  ...   55    597  35
# ..    ...  ..  ...  ...   ...   ...   ...  ...  ..  ...  ...  ...    ...  ..
# 576  1153  71  162  680  5592  1429  1037  205  29  158  ...    0    471   0
# 577  1155  76  162  750  5518  1380   871  287  28  194  ...   81    680  25
# 578  1157  83  162  836  5568  1526  1037  288  39  162  ...   75    551  57
# 579  1159  67  162  758  5517  1507  1028  278  59  142  ...    0    388   0
# 580  1161  67  162  667  5491  1353   850  311  27  165  ...   64    516  49
#
# ...

# %%
df.tail(10)
# Out:
#        ID   W    G    R    AB     H    1B   2B  3B   HR  ...  HBP  BBHBP  SF  \
# 571  1143  97  162  867  5518  1452   930  267  33  222  ...   74    701  51
# 572  1145  78  144  634  4942  1303   941  191  31  140  ...    0    468   0
# 573  1147  91  162  850  5546  1500   970  314  33  183  ...   72    777  51
# 574  1149  71  162  741  5531  1446   954  257  39  196  ...    0    501   0
# 575  1151  79  145  796  4996  1377   899  276  20  182  ...    0    549   0
# 576  1153  71  162  680  5592  1429  1037  205  29  158  ...    0    471   0
# 577  1155  76  162  750  5518  1380   871  287  28  194  ...   81    680  25
# 578  1157  83  162  836  5568  1526  1037  288  39  162  ...   75    551  57
# 579  1159  67  162  758  5517  1507  1028  278  59  142  ...    0    388   0
# 580  1161  67  162  667  5491  1353   850  311  27  165  ...   64    516  49
#
#      Outs  Outsinplay   RA        BA       OBA       SLG       OPS
# ...

# %%
df.head(10)
# Out:
#    ID   W    G    R    AB     H    1B   2B  3B   HR  ...  HBP  BBHBP  SF  \
# 0   1  60  162  558  5336  1280   891  247  31  111  ...    0    460   0
# 1   3  86  161  677  5620  1492  1147  216  46   83  ...    0    531   0
# 2   5  79  162  679  5550  1496  1088  262  63   83  ...    0    543   0
# 3   7  96  162  780  5536  1458   990  265  40  163  ...    0    561   0
# 4   9  96  162  688  5441  1354   905  247  21  181  ...   55    597  35
# 5  11  95  162  783  5497  1465   932  300  35  198  ...   65    681  52
# 6  13  83  162  861  5677  1562   969  328  21  244  ...   60    586  34
# 7  15  75  163  761  5643  1498  1114  222  39  123  ...    0    600   0
# 8  17  71  162  642  5546  1381  1000  218  29  134  ...    0    476   0
# 9  19  61  162  679  5503  1386   966  239  28  153  ...    0    443   0
#
#    Outs  Outsinplay   RA        BA       OBA       SLG       OPS
# 0  4056        3216  740  0.239880  0.300207  0.360195  0.660402
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 581 entries, 0 to 580
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          581 non-null    int64
#  1   W           581 non-null    int64
#  2   G           581 non-null    int64
#  3   R           581 non-null    int64
#  4   AB          581 non-null    int64
#  5   H           581 non-null    int64
#  6   1B          581 non-null    int64
#  7   2B          581 non-null    int64
#  8   3B          581 non-null    int64
#  9   HR          581 non-null    int64
#  10  BB          581 non-null    int64
#  11  SO          581 non-null    int64
#  12  SB          581 non-null    int64
#  13  CS          581 non-null    int64
#  14  HBP         581 non-null    int64
#  15  BBHBP       581 non-null    int64
#  16  SF          581 non-null    int64
#  17  Outs        581 non-null    int64
#  18  Outsinplay  581 non-null    int64
# ...

# %%
df.describe()
# Out:
#                 ID           W           G           R           AB  \
# count   581.000000  581.000000  581.000000  581.000000   581.000000
# mean    581.000000   79.413081  158.969019  713.099828  5432.340792
# std     335.729057   12.536626   11.372186  100.936394   396.338140
# min       1.000000   37.000000  103.000000  329.000000  3493.000000
# 25%     291.000000   71.000000  162.000000  647.000000  5462.000000
# 50%     581.000000   80.000000  162.000000  712.000000  5518.000000
# 75%     871.000000   89.000000  162.000000  783.000000  5583.000000
# max    1161.000000  116.000000  164.000000  993.000000  5781.000000
#
#                  H           1B          2B          3B          HR  ...  \
# count   581.000000   581.000000  581.000000  581.000000  581.000000  ...
# mean   1419.020654   976.506024  262.604131   32.425129  147.485370  ...
# std     130.178377    93.027538   42.435244   10.146172   40.995229  ...
# ...

# %%
df.describe(include='all')
# Out:
#                 ID           W           G           R           AB  \
# count   581.000000  581.000000  581.000000  581.000000   581.000000
# mean    581.000000   79.413081  158.969019  713.099828  5432.340792
# std     335.729057   12.536626   11.372186  100.936394   396.338140
# min       1.000000   37.000000  103.000000  329.000000  3493.000000
# 25%     291.000000   71.000000  162.000000  647.000000  5462.000000
# 50%     581.000000   80.000000  162.000000  712.000000  5518.000000
# 75%     871.000000   89.000000  162.000000  783.000000  5583.000000
# max    1161.000000  116.000000  164.000000  993.000000  5781.000000
#
#                  H           1B          2B          3B          HR  ...  \
# count   581.000000   581.000000  581.000000  581.000000  581.000000  ...
# mean   1419.020654   976.506024  262.604131   32.425129  147.485370  ...
# std     130.178377    93.027538   42.435244   10.146172   40.995229  ...
# ...

# %%
# df.describe(include='object')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df.describe(include='object')
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:12041, in NDFrame.describe(self, percentiles, include, exclude)
#   11799 @final
#   11800 def describe(
#   11801     self,
#    (...)  11804     exclude=None,
#   11805 ) -> Self:
#   11806     """
#   11807     Generate descriptive statistics.
#   11808
#    (...)  12039     max            NaN      3.0
#   12040     """
# > 12041     return describe_ndframe(
#   12042         obj=self,
#   12043         include=include,
#   12044         exclude=exclude,
#   12045         percentiles=percentiles,
#   12046     ).__finalize__(self, method="describe")
#
# ...

# %%
df.describe(include='numeric')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-6580b423ca06> in <module>
# ----> 1 df.describe(include='numeric')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10094             data = self
#   10095         else:
# > 10096             data = self.select_dtypes(include=include, exclude=exclude)
#   10097
#   10098         ldesc = [describe_1d(s) for _, s in data.items()]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in select_dtypes(self, include, exclude)
#    3565
#    3566         # convert the myriad valid dtypes object to a single representation
# -> 3567         include = frozenset(infer_dtype_from_object(x) for x in include)
#    3568         exclude = frozenset(infer_dtype_from_object(x) for x in exclude)
# ...

# %%
df.describe(exclude='object')
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(percentiles=[])
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 50%      0.000000   14.454200
# max      6.000000  512.329200

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df[df['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Pclass']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Survived']==1]['Pclass'].value_counts()
# Out:
# 1    136
# 3    119
# 2     87
# Name: Pclass, dtype: int64

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
data=pd.DataFrame([[1,2,3,np.nan],[4,np.nan,5,np.nan],[7,8,9,10],[1,np.nan,3,4],[np.nan,np.nan,np.nan,np.nan]],columns=['A','B','C','D'])

# %%
data
# Out:
#      A    B    C     D
# 0  1.0  2.0  3.0   NaN
# 1  4.0  NaN  5.0   NaN
# 2  7.0  8.0  9.0  10.0
# 3  1.0  NaN  3.0   4.0
# 4  NaN  NaN  NaN   NaN

# %%
data.dropna(how='any')
# Out:
#      A    B    C     D
# 2  7.0  8.0  9.0  10.0

# %%
data.dropna()
# Out:
#      A    B    C     D
# 2  7.0  8.0  9.0  10.0

# %%
data.dropna(how='all')
# Out:
#      A    B    C     D
# 0  1.0  2.0  3.0   NaN
# 1  4.0  NaN  5.0   NaN
# 2  7.0  8.0  9.0  10.0
# 3  1.0  NaN  3.0   4.0

# %%
data.dropna(axis=0,how='any',subset=['D','B'])
# Out:
#      A    B    C     D
# 2  7.0  8.0  9.0  10.0

# %%
data.dropna(axis=0,how='all',subset=['D','B'])
# Out:
#      A    B    C     D
# 0  1.0  2.0  3.0   NaN
# 2  7.0  8.0  9.0  10.0
# 3  1.0  NaN  3.0   4.0

# %%
data.dropna(thresh=4)
# Out:
#      A    B    C     D
# 2  7.0  8.0  9.0  10.0

# %%
df.dropna(subset=["Cabin"])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
cleaned_data = df.dropna(subset=["Cabin"])

print(cleaned_data)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['A']=data['A'].fillna(data['A'].mean())

# %%
data
# Out:
#       A    B    C     D
# 0  1.00  2.0  3.0   NaN
# 1  4.00  NaN  5.0   NaN
# 2  7.00  8.0  9.0  10.0
# 3  1.00  NaN  3.0   4.0
# 4  3.25  NaN  NaN   NaN

# %%
data['B']=data['B'].fillna(data['B'].median())

# %%
data
# Out:
#       A    B    C     D
# 0  1.00  2.0  3.0   NaN
# 1  4.00  5.0  5.0   NaN
# 2  7.00  8.0  9.0  10.0
# 3  1.00  5.0  3.0   4.0
# 4  3.25  5.0  NaN   NaN

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age']=df['Age'].fillna(df.Age.mean())

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Embarked']=df['Embarked'].fillna(df.Embarked.mode()[0])

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df.Embarked.mode()[0]
# Out:
# 'S'

# %%
data
# Out:
#       A    B    C     D
# 0  1.00  2.0  3.0   NaN
# 1  4.00  5.0  5.0   NaN
# 2  7.00  8.0  9.0  10.0
# 3  1.00  5.0  3.0   4.0
# 4  3.25  5.0  NaN   NaN

# %%
data.drop(0)
# Out:
#       A    B    C     D
# 1  4.00  5.0  5.0   NaN
# 2  7.00  8.0  9.0  10.0
# 3  1.00  5.0  3.0   4.0
# 4  3.25  5.0  NaN   NaN

# %%
df.drop(l)
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#            Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
l=df[df['Sex']=='female'].index

# %%
ds=pd.DataFrame([[1,1,2,3],[2,1,1,3],[1,1,2,3],[2,1,1,3],[1,1,2,2]],index=[7,8,9,10,11],columns=['p','q','r','s'])

# %%
ds
# Out:
#     p  q  r  s
# 7   1  1  2  3
# 8   2  1  1  3
# 9   1  1  2  3
# 10  2  1  1  3
# 11  1  1  2  2

# %%
ds.drop_duplicates()
# Out:
#     p  q  r  s
# 7   1  1  2  3
# 8   2  1  1  3
# 11  1  1  2  2

# %%
ds.drop_duplicates(keep='last')
# Out:
#     p  q  r  s
# 9   1  1  2  3
# 10  2  1  1  3
# 11  1  1  2  2

# %%
ds.drop_duplicates(keep='first')
# Out:
#     p  q  r  s
# 7   1  1  2  3
# 8   2  1  1  3
# 11  1  1  2  2

# %%
ds.drop_duplicates(subset=['p'])
# Out:
#    p  q  r  s
# 7  1  1  2  3
# 8  2  1  1  3

# %%
df3=pd.read_csv('auto-mpg.csv')
df3
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df3.horsepower.unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
df3[df3['horsepower']!='?']["horsepower"].astype('int64').mean()
# Out:
# np.float64(104.46938775510205)

# %%
df3['horsepower']=df3["horsepower"].replace('?',df3[df3['horsepower']!='?']["horsepower"].astype('int64').mean())
print(df3.horsepower.unique())
# Out:
# ['130' '165' '150' '140' '198' '220' '215' '225' '190' '170' '160' '95'
#  '97' '85' '88' '46' '87' '90' '113' '200' '210' '193'
#  np.float64(104.46938775510205) '100' '105' '175' '153' '180' '110' '72'
#  '86' '70' '76' '65' '69' '60' '80' '54' '208' '155' '112' '92' '145'
#  '137' '158' '167' '94' '107' '230' '49' '75' '91' '122' '67' '83' '78'
#  '52' '61' '93' '148' '129' '96' '71' '98' '115' '53' '81' '79' '120'
#  '152' '102' '108' '68' '58' '149' '89' '63' '48' '66' '139' '103' '125'
#  '133' '138' '135' '142' '77' '62' '132' '84' '64' '74' '116' '82']

# %%
df3.corr(numeric_only=True)
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
# origin        0.563450  -0.562543     -0.609409 -0.581024      0.205873
#
#               model year    origin
# mpg             0.579267  0.563450
# cylinders      -0.348746 -0.562543
# displacement   -0.370164 -0.609409
# weight         -0.306564 -0.581024
# acceleration    0.288137  0.205873
# model year      1.000000  0.180662
# origin          0.180662  1.000000

# %%
pd.plotting.scatter_matrix(df3,figsize=(20,20))
# Out:
# array([[<Axes: xlabel='mpg', ylabel='mpg'>,
#         <Axes: xlabel='cylinders', ylabel='mpg'>,
#         <Axes: xlabel='displacement', ylabel='mpg'>,
#         <Axes: xlabel='weight', ylabel='mpg'>,
#         <Axes: xlabel='acceleration', ylabel='mpg'>,
#         <Axes: xlabel='model year', ylabel='mpg'>,
#         <Axes: xlabel='origin', ylabel='mpg'>],
#        [<Axes: xlabel='mpg', ylabel='cylinders'>,
#         <Axes: xlabel='cylinders', ylabel='cylinders'>,
#         <Axes: xlabel='displacement', ylabel='cylinders'>,
#         <Axes: xlabel='weight', ylabel='cylinders'>,
#         <Axes: xlabel='acceleration', ylabel='cylinders'>,
#         <Axes: xlabel='model year', ylabel='cylinders'>,
#         <Axes: xlabel='origin', ylabel='cylinders'>],
#        [<Axes: xlabel='mpg', ylabel='displacement'>,
#         <Axes: xlabel='cylinders', ylabel='displacement'>,
#         <Axes: xlabel='displacement', ylabel='displacement'>,
#         <Axes: xlabel='weight', ylabel='displacement'>,
# ...

# %%
df3.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       94
# weight          351
# acceleration     95
# model year       13
# origin            3
# car name        305
# dtype: int64

# %%
df3.cylinders.value_counts()
# Out:
# cylinders
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: count, dtype: int64

# %%
pd.plotting.parallel_coordinates(df3,'cylinders',['mpg','weight','horsepower'])
# Out:
# <Axes: >

# %%
pd.crosstab(df3['cylinders'],df3['origin'],margins=True)
# Out:
# origin       1   2   3  All
# cylinders
# 3            0   0   4    4
# 4           72  63  69  204
# 5            0   3   0    3
# 6           74   4   6   84
# 8          103   0   0  103
# All        249  70  79  398

# %%
df3.sort_values('mpg')
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 28    9.0          8         304.0        193    4732          18.5
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 67   11.0          8         429.0        208    4633          11.0
# 27   11.0          8         318.0        210    4382          13.5
# ..    ...        ...           ...        ...     ...           ...
# 326  43.4          4          90.0         48    2335          23.7
# 394  44.0          4          97.0         52    2130          24.6
# 325  44.3          4          90.0         48    2085          21.7
# 329  44.6          4          91.0         67    1850          13.8
# 322  46.6          4          86.0         65    2110          17.9
#
#      model year  origin              car name
# 28           70       1              hi 1200d
# 25           70       1             ford f250
# ...

# %%
df3.sort_values('mpg',ascending=False)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 322  46.6          4          86.0         65    2110          17.9
# 329  44.6          4          91.0         67    1850          13.8
# 325  44.3          4          90.0         48    2085          21.7
# 394  44.0          4          97.0         52    2130          24.6
# 326  43.4          4          90.0         48    2335          23.7
# ..    ...        ...           ...        ...     ...           ...
# 67   11.0          8         429.0        208    4633          11.0
# 27   11.0          8         318.0        210    4382          13.5
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 28    9.0          8         304.0        193    4732          18.5
#
#      model year  origin              car name
# 322          80       3             mazda glc
# 329          80       3   honda civic 1500 gl
# ...

# %%
df3.sort_values(['mpg','displacement'],ascending=[True,False])

# %%
sns.boxenplot(y=df3['mpg'])
# Out:
# <Axes: ylabel='mpg'>

# %%
sns.boxenplot(y=df3['horsepower'])
# Out:
# <Axes: ylabel='horsepower'>

# %%
df3.horsepower.describe()
# Out:
# count     398
# unique     94
# top       150
# freq       22
# Name: horsepower, dtype: object

# %%
df3.mpg.median()
# Out:
# np.float64(23.0)

# %%
q1=df3.mpg.quantile(0.25)
print(q1)
# Out:
# 17.5

# %%
q3=df3.mpg.quantile(0.75)
print(q3)
# Out:
# 29.0

# %%
IQR=q3-q1
print(IQR)
# Out:
# 11.5

# %%
hl=q3+1.5*IQR
ll=q1-1.5*IQR
print(hl,ll)
# Out:
# 46.25 0.25

# %%
wo=df3[(df3["mpg"]>11) & (df3['mpg']<hl)]

# %%
df3.shape
# Out:
# (398, 9)

# %%
sns.boxenplot(df3["mpg"])
# Out:
# <Axes: ylabel='mpg'>

# %%
# sns.boxenplot(df3[""])    

f1=pd.DataFrame(np.random.randint(1,100,(10,4)),columns=['A','B','C','D'])
f1
# Out:
#     A   B   C   D
# 0   4  50  63  85
# 1  32  28  43  53
# 2  63  90  19  16
# 3  78  14  33  29
# 4  77  78  97  55
# 5  33  42  38  23
# 6  70  49  52  64
# 7  79  35  86  91
# 8  19  26  42  46
# 9  58  88  98  31

# %%
f1['total']=f1.apply(sum,axis=1)

# %%
f1
# Out:
#     A   B   C   D  total
# 0   4  50  63  85    202
# 1  32  28  43  53    156
# 2  63  90  19  16    188
# 3  78  14  33  29    154
# 4  77  78  97  55    307
# 5  33  42  38  23    136
# 6  70  49  52  64    235
# 7  79  35  86  91    291
# 8  19  26  42  46    133
# 9  58  88  98  31    275

# %%
f1.apply(lambda x: (x['A']+x['B']+x['C'])/3,axis=1)
# Out:
# 0    72.333333
# 1    47.666667
# 2    71.666667
# 3    73.666667
# 4    45.000000
# 5    86.333333
# 6    54.666667
# 7    55.666667
# 8    41.666667
# 9    47.666667
# dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 f1.apply(
#       2     lambda x: 'Fail' if (x['A'] < 35 or x['B'] < 35 or x['C'] < 35 or x['D'] < 35) else 'Pass',
#       3     axis=1
#       4 )
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
# ...

# %%
f1
# Out:
#     A   B   C   D  total
# 0  68  72  77   7    224
# 1  12  40  91  53    196
# 2  83  84  48  21    236
# 3  74  91  56  53    274
# 4  65  56  14  60    195
# 5  96  69  94  57    316
# 6  45  80  39  80    244
# 7  52  47  68  85    252
# 8  49  60  16  36    161
# 9  65  11  67  68    211

# %%
f1['Result']=f1.apply(
    lambda x: 'Fail' if ((x['A'] < 35) or (x['B'] < 35) or (x['C'] < 35) or (x['D'] < 35)) else 'Pass',
    axis=1
)

# %%
f1
# Out:
#     A   B   C   D  total Result
# 0  68  72  77   7    224   Fail
# 1  12  40  91  53    196   Fail
# 2  83  84  48  21    236   Fail
# 3  74  91  56  53    274   Pass
# 4  65  56  14  60    195   Fail
# 5  96  69  94  57    316   Pass
# 6  45  80  39  80    244   Pass
# 7  52  47  68  85    252   Pass
# 8  49  60  16  36    161   Fail
# 9  65  11  67  68    211   Fail

# %%
f1["sum","Max"]=f1.apply([sum,max],axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19284\3194662480.py in ?()
# ----> 1 f1["sum","Max"]=f1.apply([sum,max],axis=1)
#
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4308             self._setitem_frame(key, value)
#    4309         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4310             self._setitem_array(key, value)
#    4311         elif isinstance(value, DataFrame):
# -> 4312             self._set_item_frame_value(key, value)
#    4313         elif (
#    4314             is_list_like(value)
#    4315             and not self.columns.is_unique
#
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4466
#    4467             return self.isetitem(locs, value)
# ...

# %%
f2=pd.read_csv("ipl-matches.csv")

# %%
f2
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
f2.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
f2[f2["MatchNumber"]=="Final"][["Season","MatchNumber","Player_of_Match"]]
# Out:
#       Season MatchNumber Player_of_Match
# 0       2022       Final       HH Pandya
# 74      2021       Final    F du Plessis
# 134  2020/21       Final        TA Boult
# 194     2019       Final       JJ Bumrah
# 254     2018       Final       SR Watson
# 314     2017       Final       KH Pandya
# 373     2016       Final     BCJ Cutting
# 433     2015       Final       RG Sharma
# 492     2014       Final       MK Pandey
# 552     2013       Final      KA Pollard
# 628     2012       Final        MS Bisla
# 702     2011       Final         M Vijay
# 775  2009/10       Final        SK Raina
# 835     2009       Final        A Kumble
# 892  2007/08       Final       YK Pathan
