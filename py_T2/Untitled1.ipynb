# %%
import pandas as pd 
import numpy as np 
import seaborn as sb

print(pd.__version__)
# Out:
# 2.3.3

# %%
a=pd.Series([1,2,3],index=['A','B','C'])
a
# Out:
# A    1
# B    2
# C    3
# dtype: int64

# %%
print(a['B'])
# Out:
# 2

# %%
# DataFrame
l=[1,2,3,4,5]
l2=[6,7,8,9,10]
my_list=pd.DataFrame([l,l2],index=['x','y'],columns=['A','B','C','D','E'])
my_list
# Out:
#    A  B  C  D   E
# x  1  2  3  4   5
# y  6  7  8  9  10

# %%
my_list["total"]=my_list.apply(sum('A','),axis=0)
my_list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 my_list["total"]=my_list.apply(sum('A','B'),axis=0)
#       2 my_list
#
# TypeError: sum() can't sum strings [use ''.join(seq) instead]
