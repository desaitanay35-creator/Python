# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
x= np.array([5, 15, 25, 35, 45, 55]).reshape(-1,1)
y= np.array([5, 20, 14, 32, 22, 38])
# x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)
model= LinearRegression()
model.fit(x,y)
y_pred= model.predict(x)
print('coeficeant : ',model.coef_)
print('Intercept : ',model.intercept_)
print('r2 score : ',r2_score(y,y_pred))
x_new= np.arange(5).reshape(-1,1)
print(model.predict(x_new))
# Out:
# coeficeant :  [0.54]
# Intercept :  5.633333333333329
# r2 score :  0.715875613747954
# [5.63333333 6.17333333 6.71333333 7.25333333 7.79333333]

# %%
x_new
# Out:
# array([[0],
#        [1],
#        [2],
#        [3],
#        [4]])

# %%
x= np.array([
[500, 2005],
[700, 2008],
[900, 2010],
[650, 2007],
[800, 2009],
[1000, 2012]
])
y = np.array([20000, 30000, 40000, 28000, 35000, 45000]).reshape(-1,1)
model= LinearRegression()
model.fit(x,y)
y_pred=model.predict(x)
print(r2_score(y,y_pred))
print(model.predict([[750,2009]]))
# Out:
# 0.9995286885245901
# [[32540.98360656]]

# %%
x
# Out:
# array([[ 500, 2005],
#        [ 600, 2006],
#        [ 700, 2007]])

# %%
from sklearn.metrics import mean_squared_error
df= pd.read_csv('student_scores.csv')
df=df.dropna()
x=df.drop('Scores',axis=1)
y=df['Scores']
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=42)
model= LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print(y_pred[:5])
print(model.coef_)
print(model.intercept_)
print(mean_squared_error(y_test,y_pred))
# Out:
# [83.18814104 27.03208774 27.03208774 69.63323162 59.95115347]
# [9.68207815]
# 2.826892353899737
# 18.943211722315272

# %%
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
df= pd.read_csv('petrol_consumption.csv')
print(df.isnull().sum())
df=df.dropna()
# df=pd.get_dummies(df,drop_first=True)
# print(df.info)
x=df.drop('Petrol_Consumption',axis=1)
y=df['Petrol_Consumption']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

model=LinearRegression()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

print(y_pred[:5])
print(model.coef_)
print(model.intercept_)
print(mean_squared_error(y_test,y_pred))
print(df.head())
# Out:
# Petrol_tax                      0
# Average_income                  0
# Paved_Highways                  0
# Population_Driver_licence(%)    0
# Petrol_Consumption              0
# dtype: int64
# [606.69266519 673.77944169 584.99149034 563.53691024 519.05867235]
# [-3.69937459e+01 -5.65355145e-02 -4.38217137e-03  1.34686930e+03]
# 361.45087906652816
# 4083.255871745411
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410

# %%
import pandas as pd 
import numpy as np 
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
# df= pd.read_csv('petrol_consumption.csv')
# x=df.drop('Petrol_Consumption',axis=1)
# y=df['Petrol_Consumption']
wine=load_wine()
x=wine.data
y=wine.target
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.3,random_state=42)
KNN=KNeighborsClassifier(n_neighbors=5)
KNN.fit(x_train,y_train)
y_pred= KNN.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.664

# %%
# Using the Iris dataset 
# (https://raw.githubusercontent.com/pdsinroza/python2/main/Iris.csv?token=GHSAT0AAAAAACQ7ZNWMQ3U6FOFL37O2JIPAZ
# Q5CWZA), write Python code to perform the following tasks:
# Split the dataset into features (X) and labels (y).
# Split the features and labels into training and testing sets with a test size of 0.2 and a random state of 42.
# Initialize a kNN classifier with 3 neighbors.
# Train the classifier on the training set.
# Make predictions on the test set.
# Calculate and print the accuracy score of the classifier.

import pandas as pd 
import numpy as np
from sklearn.datasets import load_iris
from sklearn.datasets import load_wine
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,classification_report
from sklearn.model_selection import train_test_split

iris= load_iris()
x= iris.data
y=iris.target

x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=42)
knn= KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(confusion_matrix)
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix,accuracy_score
df = pd.read_csv('diabetes.csv')
df.isnull().sum()
x=df.drop('Outcome',axis=1)
y=df['Outcome']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
knn= KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
conf= confusion_matrix(y_test,y_pred)
print(conf)
print(accuracy_score(y_test,y_pred))
# Out:
# [[70 29]
#  [23 32]]
# 0.6623376623376623

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#  Given the Breast Cancer Wisconsin (Diagnostic) dataset, the objective is to build a kNN classification model that accurately 
# predicts whether a tumor is benign or malignant based on the diagnostic features provided. The model should be trained on a 
# portion of the dataset and evaluated on another portion to assess its performance. The ultimate goal is to create a reliable 
# classifier that can assist healthcare professionals in diagnosing breast cancer accurately and early. Use cancer.csv file for 
# dataset.

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
import pandas as pd
import seaborn as sns 
from sklearn.datasets import load_breast_cancer  

# df= pd.read_csv('Cancer.csv')
# df=pd.get_dummies(df,drop_first=True)
# df=df.drop('Unnamed: 32',axis=1)
# print(df.isnull().sum())
# x=df.drop('diagnosis_M',axis=1)
# y=df['diagnosis_M']
cancer = load_breast_cancer()
x= cancer.data
y=cancer.target
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

scaler= StandardScaler()
x_train_standard= scaler.fit_transform(x_train)
x_test_standard= scaler.transform(x_test)
knn= KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train_standard,y_train)
y_pred=knn.predict(x_test_standard)


accuracy = accuracy_score(y_test,y_pred)
cof= classification_report(y_test,y_pred)
print('accuracy : ',accuracy)
print('classification report : ',cof)
# Out:
# accuracy :  0.9473684210526315
# classification report :                precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        43
#            1       0.96      0.96      0.96        71
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.94      0.94       114
# weighted avg       0.95      0.95      0.95       114

# %%
df
# Out:
#    play  outlook_rainy  outlook_sunny  temp_hot  temp_mild  humidity_normal  \
# 0    no          False           True      True      False            False
# 1    no          False           True      True      False            False
# 2   yes          False          False      True      False            False
# 3   yes           True          False     False       True            False
# 4   yes           True          False     False      False             True
# 5    no           True          False     False      False             True
# 6   yes          False          False     False      False             True
# 7    no          False           True     False       True            False
# 8   yes          False           True     False      False             True
# 9   yes           True          False     False       True             True
# 10  yes          False           True     False       True             True
# ...

# %%
# The task involves building a Decision Tree classifier to predict whether to play tennis
# based on weather conditions. The dataset used for this task is the PlayTennis dataset,
# which contains information about various weather attributes such as outlook,
# temperature, humidity, and wind, along with the corresponding decision to play
# tennis or not. Use PlayTennis.csv for dataset
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import OneHotEncoder
import numpy as np 
df= pd.read_csv('PlayTennis.csv')
df.isnull().sum()
df=pd.get_dummies(df,columns=['outlook','temp','humidity','windy'],drop_first=True)
a=df.drop('play',axis=1)
b=df['play']

x_train,x_test,y_train,y_test=train_test_split(a,b,test_size=0.2,random_state=42)
dt= DecisionTreeClassifier(criterion='entropy',max_depth=26,random_state=42)
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
new_data = pd.DataFrame({'outlook': ['rainy'], 'temp': ['mild'], 'humidity': ['normal'],'windy':[False]})
missing_data = set(x.columns)-set(new_data.columns)
for cols in missing_data:
    new_data[cols]=0
new_data=new_data[x.columns]
prediction= dt.predict(new_data)
prediction[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[115], line 23
#      21 y_pred=dt.predict(x_test)
#      22 new_data = pd.DataFrame({'outlook': ['rainy'], 'temp': ['mild'], 'humidity': ['normal'],'windy':[False]})
# ---> 23 missing_data = set(x.columns)-set(new_data.columns)
#      24 for cols in missing_data:
#      25     new_data[cols]=0
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
new_data
# Out:
#   outlook  temp humidity  windy
# 0   rainy  mild   normal  False

# %%
df= pd.read_csv('PlayTennis.csv')
df
# Out:
#      outlook  temp humidity  windy play
# 0      sunny   hot     high  False   no
# 1      sunny   hot     high   True   no
# 2   overcast   hot     high  False  yes
# 3      rainy  mild     high  False  yes
# 4      rainy  cool   normal  False  yes
# 5      rainy  cool   normal   True   no
# 6   overcast  cool   normal   True  yes
# 7      sunny  mild     high  False   no
# 8      sunny  cool   normal  False  yes
# 9      rainy  mild   normal  False  yes
# 10     sunny  mild   normal   True  yes
# 11  overcast  mild     high   True  yes
# 12  overcast   hot   normal  False  yes
# 13     rainy  mild     high   True   no

# %%
df= pd.read_csv('drug200.csv')
df.isnull().sum()
df=pd.get_dummies(df,columns=[ 'Sex', 'BP', 'Cholesterol'],drop_first=True)
x=df.drop('Drug',axis=1)
y=df['Drug']
x_train,x_test,y_train,y_test= train_test_split(x,y,train_size=0.2,random_state=42)
dm= DecisionTreeClassifier(criterion='entropy',max_depth=26,random_state=42)
dm.fit(x_train,y_train)
y_pred=dm.predict(x_test)
print(classification_report(y_test,y_pred))
new_data= pd.DataFrame({'Age': [50], 'Sex': ['F'], 'BP': ['LOW'], 'Cholesterol': ['NORMAL']})
new_data=pd.get_dummies(new_data)
missing_data=set(x.columns)-set(new_data.columns)
print(new_data)
for col in missing_data:
    new_data[col]=0
missing_data
new_data=new_data[x.columns]
print(new_data)
predict=dm.predict(new_data)
predict[0]
# Out:
#               precision    recall  f1-score   support
#
#        drugA       0.00      0.00      0.00        23
#        drugB       0.80      0.29      0.42        14
#        drugC       1.00      1.00      1.00        11
#        drugX       0.56      0.98      0.71        43
#        drugY       1.00      1.00      1.00        69
#
#     accuracy                           0.79       160
#    macro avg       0.67      0.65      0.63       160
# weighted avg       0.72      0.79      0.73       160
#
#    Age  Sex_F  BP_LOW  Cholesterol_NORMAL
# 0   50   True    True                True
#    Age  Na_to_K  Sex_M  BP_LOW  BP_NORMAL  Cholesterol_NORMAL
# 0   50        0      0    True          0                True
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
df
# Out:
#      Age  Na_to_K   Drug  Sex_M  BP_LOW  BP_NORMAL  Cholesterol_NORMAL
# 0     23   25.355  drugY  False   False      False               False
# 1     47   13.093  drugC   True    True      False               False
# 2     47   10.114  drugC   True    True      False               False
# 3     28    7.798  drugX  False   False       True               False
# 4     61   18.043  drugY  False    True      False               False
# ..   ...      ...    ...    ...     ...        ...                 ...
# 195   56   11.567  drugC  False    True      False               False
# 196   16   12.006  drugC   True    True      False               False
# 197   52    9.894  drugX   True   False       True               False
# 198   23   14.020  drugX   True   False       True                True
# 199   40   11.349  drugX  False    True      False                True
#
# [200 rows x 7 columns]

# %%
import numpy as np
df=pd.read_csv('StudentsPerformance.csv')
df['math_pf']=np.where(df['math score']>50,1,0)
df['reading_pf']=np.where(df['reading score']>50,1,0)
df['writing_pf']=np.where(df['writing score']>50,1,0)

df['overall_pf']=np.where((df['math_pf']==1) & (df['reading_pf']==1) & (df['writing_pf']==1),1,0)
df=pd.get_dummies(df,columns=['gender', 'race/ethnicity', 'parental level of education', 'lunch',
       'test preparation course'])
dm = DecisionTreeClassifier(criterion='entropy',random_state=42)
df.dropna()
x=df.drop('overall_pf',axis=1)
y=df['overall_pf']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
dm.fit(x_train,y_train)
y_pred=dm.predict(x_test)
classification_report(y_test,y_pred)
cm=confusion_matrix(y_test,y_pred)

tn, fp, fn, tp = cm.ravel()
print('TN  FP  FN  TP ')
print(tn,'  ',fp,"  ",fn,'  ',tp)
# Out:
# TN  FP  FN  TP
# 46    0    0    154

# %%
df.columns
# Out:
# Index(['math score', 'reading score', 'writing score', 'math_pf', 'reading_pf',
#        'writing_pf', 'overall_pf', 'gender_female', 'gender_male',
#        'race/ethnicity_group A', 'race/ethnicity_group B',
#        'race/ethnicity_group C', 'race/ethnicity_group D',
#        'race/ethnicity_group E',
#        'parental level of education_associate's degree',
#        'parental level of education_bachelor's degree',
#        'parental level of education_high school',
#        'parental level of education_master's degree',
#        'parental level of education_some college',
#        'parental level of education_some high school', 'lunch_free/reduced',
#        'lunch_standard', 'test preparation course_completed',
#        'test preparation course_none'],
#       dtype='object')

# %%
df
# Out:
#      math score  reading score  writing score  math_pf  reading_pf  \
# 0            72             72             74        1           1
# 1            69             90             88        1           1
# 2            90             95             93        1           1
# 3            47             57             44        0           1
# 4            76             78             75        1           1
# ..          ...            ...            ...      ...         ...
# 995          88             99             95        1           1
# 996          62             55             55        1           1
# 997          59             71             65        1           1
# 998          68             78             77        1           1
# 999          77             86             86        1           1
#
#      writing_pf  overall_pf  gender_female  gender_male  \
# 0             1           1           True        False
# ...

# %%
from sklearn.tree import plot_tree
plot_tree(dt,feature_names=x.columns,filled=True,max_depth=2)
# Out:
# [Text(0.5, 0.875, 'reading_pf <= 0.5\nentropy = 0.946\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.3, 0.625, 'writing_pf <= 0.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.4, 0.75, 'True  '),
#  Text(0.2, 0.375, 'reading score <= 0.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1, 0.125, '\n  (...)  \n'),
#  Text(0.3, 0.125, '\n  (...)  \n'),
#  Text(0.4, 0.375, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7, 0.625, 'math score <= 0.5\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.6, 0.75, '  False'),
#  Text(0.6, 0.375, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8, 0.375, 'writing_pf <= 0.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7, 0.125, '\n  (...)  \n'),
#  Text(0.9, 0.125, '\n  (...)  \n')]

# %%
#Ex 3
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error 
df=pd.read_csv("Fish.csv")
x=df.drop(['Species',"Weight"],axis=1)
y=df[["Weight"]]
test=[0.75,0.80,0.85,0.90,0.95]
mse=[]
r2=[]
for i in test:
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=i,random_state=40)
    model=LinearRegression()
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)

    mse.append(mean_squared_error(y_test,y_pred))
    r2.append(r2_score(y_test,y_pred))
print(mse)
print(r2)
plt.plot(test,r2)
plt.plot(test,mse)
# Out:
# [21485.14792353189, 19141.389851256346, 24762.671477245258, 20643.648028028125, 48861.047183691735]
# [0.8482152077173417, 0.8607660310160297, 0.8173371854115964, 0.8468087122619059, 0.6289837470636086]
