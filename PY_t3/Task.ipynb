# %%
import pandas as pd 
import requests as rs
from bs4 import BeautifulSoup

# %%
with open('demo.html','r',encoding='utf-8') as f:
    res= f.read()
soup = BeautifulSoup(res,'html.parser')
box=soup.find_all('div',class_="yKfJKb row")
d={'name':[],'Rom':[],'Ram':[],'Color':[],'stars':[], 'Reviews':[],'Rear camera':[],'Front Camera':[],'Old Price':[],'New Price':[],'Discount':[],'Display(cm)':[],'Display(in)':[]}
for i in box:
    try:
        d['name'].append(i.find('div',class_='KzDlHZ').text.split('(')[0].strip())
        d['Rom'].append(i.find('li',class_='J+igdf').text.split('|')[0].strip())
        d['Ram'].append("Ram "+i.find('div',class_='KzDlHZ').text.split(',')[-1].strip(')'))
        d['Color'].append(i.find('div',class_='KzDlHZ').text.split('(')[1].split(',')[0])
        d['stars'].append(i.find('div',class_='XQDdHH').text.strip())
        d['Reviews'].append(i.find('span',class_="Wphh3N").text.split('&')[1].strip())
        d['Rear camera'].append(i.find('li',class_="J+igdf").text.split('|')[1].split('Display')[1].strip())
        d['Front Camera'].append(i.find('li',class_="J+igdf").text.split('|')[2].split('Camera')[0].strip())
        d['Display(cm)'].append(i.find('li',class_="J+igdf").text.split('ROM')[1].split('(')[0].strip())
        d['Display(in)'].append(i.find('li',class_="J+igdf").text.split('(')[1].split(')')[0].strip())
    except:
        d['name'].append('NaN')
        d['Rom'].append('NaN')
        d['Ram'].append('NaN')
        d['Color'].append('NaN')
        d['stars'].append('NaN')
        d['Rear camera'].append('NaN')
        d['Front Camera'].append('NaN')
        d['Display(cm)'].append('NaN')
        d['Display(in)'].append('NaN')
        
    
    
        
    try:
        d['Old Price'].append(i.find('div',class_="yRaY8j ZYYwLA").text.split('₹')[1].strip())
    except:
        d['Old Price'].append('NaN')
    try:
        d['New Price'].append(i.find('div',class_="Nx9bqj _4b5DiR").text.split('₹')[1].strip())
    except:
        d['New Price'].append('NaN')
        
    try:
        d['Discount'].append(i.find('div',class_="UkUFwK").text.strip())
        
    except:
        d['Discount'].append('NaN')
        
        # d['Display(cm)'].append('NaN')
        # d['Display(in)'].append('NaN')
        # d['Discount'].append('NaN')

# %%
# d['name'].append(box[0].find_all('div',class_='KzDlHZ').text.strip())
d
# Out:
# {'name': ['Google Pixel 7',
#   'Google Pixel 9A',
#   'Google Pixel 8a',
#   'Google Pixel 9A',
#   'Google Pixel 7',
#   'Google Pixel 8a',
#   'Google Pixel 9A',
#   'Google Pixel 7a',
#   'Google Pixel 8a',
#   'Google Pixel 8a',
#   'Google Pixel 7a',
#   'Google Pixel 8',
#   'Google Pixel 7a',
#   'Google Pixel 8a',
#   'Google Pixel 9 Pro Fold',
#   'Google Pixel 9 Pro',
#   'Google Pixel 8 Pro',
#   'Google Pixel 8 Pro',
#   'Google Pixel 8',
#   'Google Pixel 9 Pro',
#   'Google Pixel 9 Pro XL',
#   'Google Pixel 9',
#   'Google Pixel 9',
#   'Google Pixel 6a'],
#  'Rom': ['8 GB RAM',
#   '8 GB RAM',
#   '8 GB RAM',
#   '8 GB RAM',
#   '8 GB RAM',
#   '8 GB RAM',
#   '8 GB RAM',
#   '8 GB RAM',
#   '8 GB RAM',
#   '8 GB RAM',
#   '8 GB RAM',
#   '8 GB RAM',
#   '8 GB RAM',
#   '8 GB RAM',
#   '16 GB RAM',
#   '16 GB RAM',
#   '12 GB RAM',
#   '12 GB RAM',
#   '8 GB RAM',
#   '16 GB RAM',
#   '16 GB RAM',
#   '12 GB RAM',
#   '12 GB RAM',
#   '6 GB RAM'],
#  'Ram': ['Ram  128 GB',
#   'Ram  256 GB',
#   'Ram  128 GB',
#   'Ram  256 GB',
#   'Ram  128 GB',
#   'Ram  128 GB',
#   'Ram  256 GB',
#   'Ram  128 GB',
#   'Ram  128 GB',
#   'Ram  128 GB',
#   'Ram  128 GB',
#   'Ram  128 GB',
#   'Ram  128 GB',
#   'Ram  256 GB',
#   'Ram  256 GB',
#   'Ram  256 GB',
#   'Ram  128 GB',
#   'Ram  128 GB',
#   'Ram  128 GB',
#   'Ram  256 GB',
#   'Ram  512 GB',
#   'Ram  256 GB',
#   'Ram  256 GB',
#   'Ram  128 GB'],
#  'Color': ['Snow',
#   'Obsidian',
#   'Obsidian',
#   'Iris',
#   'Lemongrass',
#   'Porcelain',
#   'Porcelain',
#   'Charcoal',
#   'Aloe',
#   'Bay',
#   'Snow',
#   'Rose',
#   'Sea',
#   'Obsidian',
#   'Obsidian',
#   'Hazel',
#   'Obsidian',
#   'Bay',
#   'Hazel',
#   'Porcelain',
#   'Obsidian',
#   'Peony',
#   'Obsidian',
#   'Chalk'],
#  'stars': ['4.3',
#   '4.5',
#   '4.3',
#   '4.5',
#   '4.3',
#   '4.3',
#   '4.5',
#   '4.1',
#   '4.3',
#   '4.3',
#   '4.1',
#   '4.4',
#   '4.1',
#   '4.3',
#   '4.5',
#   '4.6',
#   '4.4',
#   '4.4',
#   '4.4',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.3'],
#  'Reviews': ['2,089 Reviews',
#   '123 Reviews',
#   '517 Reviews',
#   '123 Reviews',
#   '2,089 Reviews',
#   '517 Reviews',
#   '123 Reviews',
#   '2,685 Reviews',
#   '517 Reviews',
#   '517 Reviews',
#   '2,685 Reviews',
#   '1,428 Reviews',
#   '2,685 Reviews',
#   '517 Reviews',
#   '12 Reviews',
#   '58 Reviews',
#   '119 Reviews',
#   '119 Reviews',
#   '1,428 Reviews',
#   '58 Reviews',
#   '60 Reviews',
#   '293 Reviews',
#   '293 Reviews',
#   '8,533 Reviews'],
#  'Rear camera': ['50MP + 12MP',
#   '48MP + 12MP',
#   '64MP + 13MP',
#   '48MP + 12MP',
#   '50MP + 12MP',
#   '64MP + 13MP',
#   '48MP + 12MP',
#   '64MP (OIS) + 13MP',
#   '64MP + 13MP',
#   '64MP + 13MP',
#   '64MP (OIS) + 13MP',
#   '50MP + 12MP',
#   '64MP (OIS) + 13MP',
#   '64MP + 13MP',
#   '48MP + 10.5MP + 10.8MP',
#   '50MP + 48MP + 48MP',
#   '50MP + 48MP + 48MP',
#   '50MP + 48MP + 48MP',
#   '50MP + 12MP',
#   '50MP + 48MP + 48MP',
#   '50MP + 48MP + 48MP',
#   '50MP + 48MP',
#   '50MP + 48MP',
#   '12.2MP + 12MP'],
#  'Front Camera': ['10.8MP Front',
#   '12MP Front',
#   '13MP Front',
#   '12MP Front',
#   '10.8MP Front',
#   '13MP Front',
#   '12MP Front',
#   '13MP Front',
#   '13MP Front',
#   '13MP Front',
#   '13MP Front',
#   '10.5MP Front',
#   '13MP Front',
#   '13MP Front',
#   '10MP Front',
#   '42MP Front',
#   '10.5MP Front',
#   '10.5MP Front',
#   '10.5MP Front',
#   '42MP Front',
#   '42MP Front',
#   '10.5MP Front',
#   '10.5MP Front',
#   '8MP Front'],
#  'Old Price': ['59,999',
#   'NaN',
#   '52,999',
#   'NaN',
#   '59,999',
#   '52,999',
#   'NaN',
#   '43,999',
#   '52,999',
#   '52,999',
#   '43,999',
#   '75,999',
#   '43,999',
#   '59,999',
#   '1,72,999',
#   '1,09,999',
#   '1,06,999',
#   '1,06,999',
#   '75,999',
#   '1,09,999',
#   '1,39,999',
#   '79,999',
#   '79,999',
#   '43,999'],
#  'New Price': ['30,999',
#   '49,999',
#   '37,999',
#   '49,999',
#   '30,999',
#   '37,999',
#   '49,999',
#   '27,999',
#   '37,999',
#   '37,999',
#   '27,999',
#   '44,999',
#   '27,999',
#   '44,999',
#   '1,52,999',
#   '89,999',
#   '59,999',
#   '59,999',
#   '44,999',
#   '89,999',
#   '1,19,999',
#   '74,999',
#   '74,999',
#   '43,989'],
#  'Discount': ['48% off',
#   'NaN',
#   '28% off',
#   'NaN',
#   '48% off',
#   '28% off',
#   'NaN',
#   '36% off',
#   '28% off',
#   '28% off',
#   '36% off',
#   '40% off',
#   '36% off',
#   '25% off',
#   '11% off',
#   '18% off',
#   '43% off',
#   '43% off',
#   '40% off',
#   '18% off',
#   '14% off',
#   '6% off',
#   '6% off',
#   'NaN'],
#  'Display(cm)': ['16.0 cm',
#   '15.96 cm',
#   '15.49 cm',
#   '15.96 cm',
#   '16.0 cm',
#   '15.49 cm',
#   '15.96 cm',
#   '15.49 cm',
#   '15.49 cm',
#   '15.49 cm',
#   '15.49 cm',
#   '15.75 cm',
#   '15.49 cm',
#   '15.49 cm',
#   '16.0 cm',
#   '16.0 cm',
#   '17.02 cm',
#   '17.02 cm',
#   '15.75 cm',
#   '16.0 cm',
#   '17.27 cm',
#   '16.0 cm',
#   '16.0 cm',
#   '15.6 cm'],
#  'Display(in)': ['6.3 inch',
#   '6.285 inch',
#   '6.1 inch',
#   '6.285 inch',
#   '6.3 inch',
#   '6.1 inch',
#   '6.285 inch',
#   '6.1 inch',
#   '6.1 inch',
#   '6.1 inch',
#   '6.1 inch',
#   '6.2 inch',
#   '6.1 inch',
#   '6.1 inch',
#   '6.3 inch',
#   '6.3 inch',
#   '6.7 inch',
#   '6.7 inch',
#   '6.2 inch',
#   '6.3 inch',
#   '6.8 inch',
#   '6.3 inch',
#   '6.3 inch',
#   '6.14 inch']}

# %%
df= pd.DataFrame(d)

# %%
df
# Out:
#                        name        Rom          Ram       Color stars  \
# 0            Google Pixel 7   8 GB RAM  Ram  128 GB        Snow   4.3
# 1           Google Pixel 9A   8 GB RAM  Ram  256 GB    Obsidian   4.5
# 2           Google Pixel 8a   8 GB RAM  Ram  128 GB    Obsidian   4.3
# 3           Google Pixel 9A   8 GB RAM  Ram  256 GB        Iris   4.5
# 4            Google Pixel 7   8 GB RAM  Ram  128 GB  Lemongrass   4.3
# 5           Google Pixel 8a   8 GB RAM  Ram  128 GB   Porcelain   4.3
# 6           Google Pixel 9A   8 GB RAM  Ram  256 GB   Porcelain   4.5
# 7           Google Pixel 7a   8 GB RAM  Ram  128 GB    Charcoal   4.1
# 8           Google Pixel 8a   8 GB RAM  Ram  128 GB        Aloe   4.3
# 9           Google Pixel 8a   8 GB RAM  Ram  128 GB         Bay   4.3
# 10          Google Pixel 7a   8 GB RAM  Ram  128 GB        Snow   4.1
# 11           Google Pixel 8   8 GB RAM  Ram  128 GB        Rose   4.4
# 12          Google Pixel 7a   8 GB RAM  Ram  128 GB         Sea   4.1
# 13          Google Pixel 8a   8 GB RAM  Ram  256 GB    Obsidian   4.3
# 14  Google Pixel 9 Pro Fold  16 GB RAM  Ram  256 GB    Obsidian   4.5
# 15       Google Pixel 9 Pro  16 GB RAM  Ram  256 GB       Hazel   4.6
# 16       Google Pixel 8 Pro  12 GB RAM  Ram  128 GB    Obsidian   4.4
# 17       Google Pixel 8 Pro  12 GB RAM  Ram  128 GB         Bay   4.4
# 18           Google Pixel 8   8 GB RAM  Ram  128 GB       Hazel   4.4
# 19       Google Pixel 9 Pro  16 GB RAM  Ram  256 GB   Porcelain   4.6
# 20    Google Pixel 9 Pro XL  16 GB RAM  Ram  512 GB    Obsidian   4.6
# 21           Google Pixel 9  12 GB RAM  Ram  256 GB       Peony   4.6
# 22           Google Pixel 9  12 GB RAM  Ram  256 GB    Obsidian   4.6
# 23          Google Pixel 6a   6 GB RAM  Ram  128 GB       Chalk   4.3
#
#           Reviews             Rear camera  Front Camera Old Price New Price  \
# 0   2,089 Reviews             50MP + 12MP  10.8MP Front    59,999    30,999
# 1     123 Reviews             48MP + 12MP    12MP Front       NaN    49,999
