# %%
import requests as rs
from bs4 import BeautifulSoup

# %%
html='''<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <h1>Welcome To my website </h1>
    <h1>HTML Basics</h1>

    <p>This is first page</p>
    <p>This is 2nd page</p>
    <ul>
    <li>Hello</li>
    <li>Hi</li>
    </ul>
</body>
</html>'''

# %%
soup=BeautifulSoup(html,'html.parser')
# soup=BeautifulSoup(html)  also valid default'html.parser'
print(soup.find('title').text)
print(soup.find('h1').text)
print(soup.find_all('h1'))
# Out:
# Document
# Welcome To my website
# [<h1>Welcome To my website </h1>, <h1>HTML Basics</h1>]

# %%
soup.h1
for i in soup.find_all('h1'):
    print(i.text)
# Out:
# Welcome To my website
# HTML Basics

# %%
box= soup.find('ul')
# Out:
#   Cell In[23], line 1
#     box=
#          ^
# SyntaxError: invalid syntax

# %%
url='https://webscraper.io/test-sites/e-commerce/allinone'
responce= rs.get(url)
result=responce.text
# print(result)
print(responce.status_code)


soup=BeautifulSoup(result,'html.parser')
print(soup.find('h1').text)
print(soup.find('div',class_='jumbotron'))
print(soup.find('div',class_='jumbotron').find('h2').text)
print(soup.find('p',class_='lead').text)
# Out:
# 200
# Test Sites
# <div class="jumbotron">
# <h2>E-commerce training site</h2>
# <p class="lead">
# 			Welcome to WebScraper e-commerce site. You can use this site for training
# 			to learn how to use the Web Scraper. Items listed here are not for sale.
# 		</p>
# </div>
# E-commerce training site
#
# 			Welcome to WebScraper e-commerce site. You can use this site for training
# 			to learn how to use the Web Scraper. Items listed here are not for sale.

# %%
url2 = 'https://webscraper.io/test-sites/e-commerce/allinone/computers/tablets'
response = rs.get(url2)
soup=BeautifulSoup(response.text,'html.parser')

# %%
box= soup.find_all('div',class_="col-md-4 col-xl-4 col-lg-4")
print(len(box))
# Out:
# 21

# %%
d= {'name':[],'price':[],'reviews':[]}
for i in box:
    d['name'].append(i.find('a',class_='title').text.strip())
    d['price'].append(i.find('span').text.strip())
    d['reviews'].append(i.find('p',class_='review-count float-end').text.strip())
import pandas as pd
df=pd.DataFrame(d)
print(df.head)
# Out:
# <bound method NDFrame.head of                  name    price     reviews
# 0      Lenovo IdeaTab   $69.99   7 reviews
# 1      IdeaTab A3500L   $88.99   7 reviews
# 2         Acer Iconia   $96.99   7 reviews
# 3        Galaxy Tab 3   $97.99   2 reviews
# 4   Iconia B1-730H...   $99.99   1 reviews
# 5       Memo Pad HD 7  $101.99  10 reviews
# 6       Asus MeMO Pad  $102.99  14 reviews
# 7       Amazon Kindle  $103.99   3 reviews
# 8        Galaxy Tab 3  $107.99  14 reviews
# 9       IdeaTab A8-50  $121.99  13 reviews
# 10         MeMO Pad 7  $130.99  11 reviews
# 11  IdeaTab A3500-...  $148.99   9 reviews
# 12      IdeaTab S5000  $172.99   8 reviews
# 13       Galaxy Tab 4  $233.99   1 reviews
# 14         Galaxy Tab  $251.99  14 reviews
# 15  MeMo PAD FHD 1...  $320.99   7 reviews
# 16        Galaxy Note  $399.99  12 reviews
# 17        Galaxy Note  $489.99   9 reviews
# 18  iPad Mini Reti...  $537.99   8 reviews
# 19  Galaxy Note 10...  $587.99   6 reviews
# ...

# %%
url3='https://www.iplt20.com/points-table/men'
responce= rs.get(url3)
soup3= BeautifulSoup(responce.text,'html.parser')

# %%
# table= soup.find('table',class_='ih-td-tab')
# print(table)

# %%
url4='https://subslikescript.com/movie/Titanic-120338'
response = rs.get(url4)
soup=BeautifulSoup(response.text,'html.parser')

# %%
box=soup.find('article',class_='main-article')
print(box.h1.text)
# Out:
# Titanic (1997) - full transcript

# %%
box2=soup.find('div',class_="full-script").text.strip()
print(box2)
# Out:
# 13 meters. You should see it.
#
#
# Okay, take her up and over the bow rail.
#
#
# Mir 2, we're going over the bow.
# Stay with us.
#
#
# Okay, quiet. We're rolling.
#
#
# Seeing her coming out of the
# darkness like a ghost ship...
#
#
# still gets me every time.
#
#
# To see the sad ruin of the
# great ship sitting here...
#
#
# where she landed at
# 2:30 in the morning
#
#
# of April 15, 1912...
#
#
# after her long fall...
#
#
# from the world above.
#
#
# You are so full of shit, boss.
#
#
# Dive 6. Here we are again
# on the deck of Titanic.
#
#
# 21/2 miles down. 3,821 meters.
#
#
# The pressure outside is
# 31/2 tons per square inch.
#
#
# These windows are
# 9 inches thick.
#
#
# If they go, it's sayonara
# in two microseconds.
#
#
# All right, enough of that bullshit.
#
#
# Just put her down on the roof of
# the officers' quarters like yesterday.
#
#
# Mir 2, we're landing right over the
# Grand Staircase. You guys set to launch?
#
#
# Yeah, Brock. Launching Dunkin now.
# ...

# %%
url5='https://subslikescript.com/movies_letter-H'
responce = rs.get(url5)
soup6= BeautifulSoup(responce.text,'html.parser')

# %%
Hlist= soup6.find('article',class_="main-article")
link_list=[]
for i in soup6.find_all('a'):
    link_list.append('https://subslikescript.com/'+i['href'])
print(link_list)
# Out:
# ['https://subslikescript.com//', 'https://subslikescript.com//movies', 'https://subslikescript.com//series', 'https://subslikescript.com//', 'https://subslikescript.com//movies', 'https://subslikescript.com//movies_letter-sign', 'https://subslikescript.com//movies_letter-A', 'https://subslikescript.com//movies_letter-B', 'https://subslikescript.com//movies_letter-C', 'https://subslikescript.com//movies_letter-D', 'https://subslikescript.com//movies_letter-E', 'https://subslikescript.com//movies_letter-F', 'https://subslikescript.com//movies_letter-G', 'https://subslikescript.com//movies_letter-H', 'https://subslikescript.com//movies_letter-I', 'https://subslikescript.com//movies_letter-J', 'https://subslikescript.com//movies_letter-K', 'https://subslikescript.com//movies_letter-L', 'https://subslikescript.com//movies_letter-M', 'https://subslikescript.com//movies_letter-N', 'https://subslikescript.com//movies_letter-O', 'https://subslikescript.com//movies_letter-P', 'https://subslike
# ...

# %% [markdown]
# Q1 20/05/26

# %%
import pandas as pd
import  numpy as np
from bs4 import  BeautifulSoup

# %%
with open('vishal_new.html','r',encoding='utf-8') as f:
    res=f.read()

# %%
soup= BeautifulSoup(res,'html.parser')

# %%
box= soup.find_all('div',class_="_2kHMtA")
print(len(box))
# Out:
# 24

# %%
d= {'mobilename':[], 'stars':[],'rating':[],'review':[],'camera':[],'new_price':[],'old_price':[],'discount':[]}
mobiles=soup.find_all('div',class_='_3pLy-c row')
print(mobiles[0])
for i in box:
    try:
        d['mobilename'].append(i.find('div',class_='_4rR01T').text.strip())
        d['stars'].append(i.find('div',class_='_3LWZlK').text.strip())
        d['rating'].append(i.find('span',class_='_2_R_DZ').text.split('&')[0].strip())
        d['review'].append(i.find('span',class_='_2_R_DZ').text.split('&')[1].strip())
        d['camera'].append(i.find('ul',class_='_1xgFaf').find_all('li')[1].text.strip())
        d['new_price'].append(i.find('div',class_='_30jeq3 _1_WHN1').text.strip())
        d['old_price'].append(i.find('div',class_='_3I9_wc _27UcVY').text.strip())
        d['discount'].append(i.find('div',class_='_3Ay6Sb').text.strip())
    except:
        d['old_price'].append('Data Not found')
        d['new_price'].append('Data Not found')
        d['discount'].append('Data Not found')
        
    

for i in range(0,24):
    print(f'Mobile name : {d['mobilename'][i]}')
    print(f'Mobile stars : {d['stars'][i]}')
    print(f'Mobile rating : {d['rating'][i]}')
    print(f'Mobile review : {d['review'][i]}')
    print(f'Mobile camera : {d['camera'][i]}')
    print(f'Mobile new_price : {d['new_price'][i]}')
    print(f'Mobile old_price : {d['old_price'][i]}')
    print(f'Mobile discount : {d['discount'][i]}')

    print()
    print()
    print()
    print()
    print()
# Out:
# <div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">Huawei P9 (Mystic Silver, 32 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBEKQHYS6ZHQRBJKD3SDB_MOBEKQHYS6ZHQRBJ_"><div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>829 Ratings </span><span class="_13vcmD">&amp;</span><span> 265 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">3 GB RAM | 32 GB ROM | Expandable Upto 128 GB</li><li class="rgWa7D">13.21 cm (5.2 inch) Full HD Display</li><li class="rgWa7D">12MP + 12MP | 8MP Front Camera</li><li class="rgWa7D">3000 mAh Battery</li><li class="rgWa7D">HUAWEI Kirin 955 ARM Cortex-A72 64-bit + ARM Cortex-A53 64-bit Processor</li><li class="rgWa7D">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹39,9
# ...

# %%
mobiles[0].find('ul',class_='_1xgFaf').find_all('li')[1].text.strip()
# Out:
# '13.21 cm (5.2 inch) Full HD Display'

# %%
with open('List of state and union territory capitals in India - Wikipedia (5_28_2025 8：46：50 AM).html','r',encoding='utf-8') as f2:
    res2=f2.read()
soup2= BeautifulSoup(res2)
box=soup2.find('table',class_="wikitable sortable jquery-tablesorter")
# soup2

# %%
cols={'State':[],	'Administrative':[],
'Executive capital':[],	'Legislative capital':[],	'Judicial capital':[],	'Year of establishment':[],	'Former capital':[]}
colname= box.find('thead')
colname
# for i in box
# Out:
# -1

# %%
soup2.find('tbody').find_all('tr')[0].find_all('td')[0].text.strip()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 soup2.find('tbody').find_all('tr')[0].find_all('td')[0].text.strip()
#
# IndexError: list index out of range

# %%
tables = soup2.find_all('tbody')

print(len(tables))
# Out:
# 4

# %%
box.find('tbody').find_all('tr')[0].find_all('td')[0].text.strip()
# Out:
# 'Andhra Pradesh'
